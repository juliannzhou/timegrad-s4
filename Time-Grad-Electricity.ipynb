# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

# %%
# from pts.model.tempflow import TempFlowEstimator
from pts.model.time_grad import TimeGradEstimator
# from pts.model.transformer_tempflow import TransformerTempFlowEstimator
# from pts import Trainer
from pytorch_lightning import Trainer

# %%
from diffusers import (
    PNDMScheduler,
    DDIMScheduler,
    DPMSolverMultistepScheduler,
    KDPM2DiscreteScheduler,
    DEISMultistepScheduler,
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def plot(target, forecast, prediction_length, prediction_intervals=(50.0, 90.0), color='g', fname=None):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape
    
    ps = [50.0] + [
            50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
        ]
        
    percentiles_sorted = sorted(set(ps))
    
    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3
        
    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)
        
        ps_data = [forecast.quantile(p / 100.0)[:,dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2
        
        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)
        
        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1]    
    axx[0].legend(legend, loc="upper left")
    
    if fname is not None:
        plt.savefig(fname, bbox_inches='tight', pad_inches=0.05)

# %%
print(f"Available datasets: {list(dataset_recipes.keys())}")
# Out:
# Available datasets: ['constant', 'exchange_rate', 'solar-energy', 'electricity', 'traffic', 'exchange_rate_nips', 'electricity_nips', 'traffic_nips', 'solar_nips', 'wiki2000_nips', 'wiki-rolling_nips', 'taxi_30min', 'kaggle_web_traffic_with_missing', 'kaggle_web_traffic_without_missing', 'kaggle_web_traffic_weekly', 'm1_yearly', 'm1_quarterly', 'm1_monthly', 'nn5_daily_with_missing', 'nn5_daily_without_missing', 'nn5_weekly', 'tourism_monthly', 'tourism_quarterly', 'tourism_yearly', 'cif_2016', 'london_smart_meters_without_missing', 'wind_farms_without_missing', 'car_parts_without_missing', 'dominick', 'fred_md', 'pedestrian_counts', 'hospital', 'covid_deaths', 'kdd_cup_2018_without_missing', 'weather', 'm3_monthly', 'm3_quarterly', 'm3_yearly', 'm3_other', 'm4_hourly', 'm4_daily', 'm4_weekly', 'm4_monthly', 'm4_quarterly', 'm4_yearly', 'm5', 'uber_tlc_daily', 'uber_tlc_hourly', 'airpassengers', 'australian_electricity_demand', 'electricity_hourly', 'electricity_weekly', 'rideshare_without_missing', 'saugeenday', 'solar_10_minutes', 'solar_weekly', 'sunspot_without_missing', 'temperature_rain_without_missing', 'vehicle_trips_without_missing']

# %%
# exchange_rate_nips, electricity_nips, traffic_nips, solar_nips, wiki-rolling_nips, ## taxi_30min is buggy still
dataset = get_dataset("electricity_nips", regenerate=False)

# %%
dataset.metadata
# Out:
# MetaData(freq='H', target=None, feat_static_cat=[CategoricalFeatureInfo(name='feat_static_cat_0', cardinality='370')], feat_static_real=[], feat_dynamic_real=[], feat_dynamic_cat=[], prediction_length=24)

# %%
train_grouper = MultivariateGrouper(max_target_dim=min(2000, int(dataset.metadata.feat_static_cat[0].cardinality)))

test_grouper = MultivariateGrouper(num_test_dates=int(len(dataset.test)/len(dataset.train)), 
                                   max_target_dim=min(2000, int(dataset.metadata.feat_static_cat[0].cardinality)))

# %%
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
scheduler = DEISMultistepScheduler(
    num_train_timesteps=150,
    beta_end=0.1,
)

# %%
estimator = TimeGradEstimator(
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    hidden_size=64,
    num_layers=2,
    dropout_rate=0.1,
    lags_seq=[1],
    scheduler=scheduler,
    num_inference_steps=149,
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length * 3,
    freq=dataset.metadata.freq,
    scaling="mean",
    trainer_kwargs=dict(max_epochs=20, devices="1"),
)

# %%
predictor = estimator.train(dataset_train, num_workers=8)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name  | Type          | Params | In sizes | Out sizes
# -----------------------------------------------------------------------
# 0 | model | TimeGradModel | 432 K  | ?        | [1, 100, 24, 370]
# -----------------------------------------------------------------------
# 432 K     Trainable params
# 0         Non-trainable params
# 432 K     Total params
# 1.729     Total estimated model params size (MB)
# Training: |          | 0/? [00:00<?, ?it/s]
# Epoch 0, global step 50: 'train_loss' reached 0.34833 (best 0.34833), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 0.10945 (best 0.10945), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 0.06175 (best 0.06175), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 0.04934 (best 0.04934), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 0.04608 (best 0.04608), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' reached 0.04338 (best 0.04338), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=5-step=300.ckpt' as top 1
# Epoch 6, global step 350: 'train_loss' reached 0.04287 (best 0.04287), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' reached 0.04142 (best 0.04142), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' reached 0.03978 (best 0.03978), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=8-step=450.ckpt' as top 1
# Epoch 9, global step 500: 'train_loss' reached 0.03965 (best 0.03965), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' reached 0.03867 (best 0.03867), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=10-step=550.ckpt' as top 1
# Epoch 11, global step 600: 'train_loss' reached 0.03766 (best 0.03766), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=11-step=600.ckpt' as top 1
# Epoch 12, global step 650: 'train_loss' reached 0.03688 (best 0.03688), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=12-step=650.ckpt' as top 1
# Epoch 13, global step 700: 'train_loss' was not in top 1
# Epoch 14, global step 750: 'train_loss' reached 0.03656 (best 0.03656), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=14-step=750.ckpt' as top 1
# Epoch 15, global step 800: 'train_loss' was not in top 1
# Epoch 16, global step 850: 'train_loss' was not in top 1
# Epoch 17, global step 900: 'train_loss' reached 0.03555 (best 0.03555), saving model to '/Users/kwunyingzhou/pytorch-ts/lightning_logs/version_0/checkpoints/epoch=17-step=900.ckpt' as top 1
# Epoch 18, global step 950: 'train_loss' was not in top 1
# Epoch 19, global step 1000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=20` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(dataset=dataset_test,
                                                 predictor=predictor,
                                                 num_samples=100)

# %%
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()

# %%
evaluator = MultivariateEvaluator(quantiles=(np.arange(20)/20.0)[1:], 
                                  target_agg_funcs={'sum': np.sum})

# %%
agg_metric, item_metrics = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 99.93it/s]
# Running evaluation: 7it [00:00, 115.91it/s]
# Running evaluation: 7it [00:00, 129.72it/s]
# Running evaluation: 7it [00:00, 123.73it/s]
# Running evaluation: 7it [00:00, 131.70it/s]
# Running evaluation: 7it [00:00, 120.43it/s]
# Running evaluation: 7it [00:00, 122.27it/s]
# Running evaluation: 7it [00:00, 123.91it/s]
# Running evaluation: 7it [00:00, 134.85it/s]
# Running evaluation: 7it [00:00, 128.08it/s]
# Running evaluation: 7it [00:00, 131.27it/s]
# Running evaluation: 7it [00:00, 129.11it/s]
# Running evaluation: 7it [00:00, 134.22it/s]
# Running evaluation: 7it [00:00, 125.06it/s]
# Running evaluation: 7it [00:00, 135.99it/s]
# Running evaluation: 7it [00:00, 130.41it/s]
# Running evaluation: 7it [00:00, 127.63it/s]
# Running evaluation: 7it [00:00, 128.58it/s]
# Running evaluation: 7it [00:00, 125.07it/s]
# Running evaluation: 7it [00:00, 130.90it/s]
# Running evaluation: 7it [00:00, 129.53it/s]
# Running evaluation: 7it [00:00, 125.81it/s]
# Running evaluation: 7it [00:00, 126.95it/s]
# Running evaluation: 7it [00:00, 126.67it/s]
# Running evaluation: 7it [00:00, 128.64it/s]
# Running evaluation: 7it [00:00, 128.10it/s]
# Running evaluation: 7it [00:00, 127.12it/s]
# Running evaluation: 7it [00:00, 123.16it/s]
# Running evaluation: 7it [00:00, 111.75it/s]
# Running evaluation: 7it [00:00, 135.93it/s]
# Running evaluation: 7it [00:00, 130.63it/s]
# Running evaluation: 7it [00:00, 128.29it/s]
# Running evaluation: 7it [00:00, 131.41it/s]
# Running evaluation: 7it [00:00, 130.40it/s]
# Running evaluation: 7it [00:00, 134.14it/s]
# Running evaluation: 7it [00:00, 131.08it/s]
# Running evaluation: 7it [00:00, 126.89it/s]
# Running evaluation: 7it [00:00, 138.12it/s]
# Running evaluation: 7it [00:00, 136.39it/s]
# Running evaluation: 7it [00:00, 128.36it/s]
# Running evaluation: 7it [00:00, 126.32it/s]
# Running evaluation: 7it [00:00, 128.93it/s]
# Running evaluation: 7it [00:00, 133.21it/s]
# Running evaluation: 7it [00:00, 127.50it/s]
# Running evaluation: 7it [00:00, 123.41it/s]
# Running evaluation: 7it [00:00, 131.96it/s]
# Running evaluation: 7it [00:00, 125.75it/s]
# Running evaluation: 7it [00:00, 124.63it/s]
# Running evaluation: 7it [00:00, 129.09it/s]
# Running evaluation: 7it [00:00, 122.00it/s]
# Running evaluation: 7it [00:00, 137.06it/s]
# Running evaluation: 7it [00:00, 128.79it/s]
# Running evaluation: 7it [00:00, 123.44it/s]
# Running evaluation: 7it [00:00, 127.67it/s]
# Running evaluation: 7it [00:00, 131.39it/s]
# Running evaluation: 7it [00:00, 117.71it/s]
# Running evaluation: 7it [00:00, 129.25it/s]
# Running evaluation: 7it [00:00, 127.02it/s]
# Running evaluation: 7it [00:00, 128.40it/s]
# Running evaluation: 7it [00:00, 117.67it/s]
# Running evaluation: 7it [00:00, 122.06it/s]
# Running evaluation: 7it [00:00, 123.82it/s]
# Running evaluation: 7it [00:00, 128.22it/s]
# Running evaluation: 7it [00:00, 135.07it/s]
# Running evaluation: 7it [00:00, 94.39it/s]
# Running evaluation: 7it [00:00, 120.08it/s]
# Running evaluation: 7it [00:00, 121.75it/s]
# Running evaluation: 7it [00:00, 124.52it/s]
# Running evaluation: 7it [00:00, 124.46it/s]
# Running evaluation: 7it [00:00, 126.37it/s]
# Running evaluation: 7it [00:00, 123.37it/s]
# Running evaluation: 7it [00:00, 123.87it/s]
# Running evaluation: 7it [00:00, 131.09it/s]
# Running evaluation: 7it [00:00, 128.04it/s]
# Running evaluation: 7it [00:00, 132.34it/s]
# Running evaluation: 7it [00:00, 130.49it/s]
# Running evaluation: 7it [00:00, 127.24it/s]
# Running evaluation: 7it [00:00, 123.34it/s]
# Running evaluation: 7it [00:00, 126.46it/s]
# Running evaluation: 7it [00:00, 128.63it/s]
# Running evaluation: 7it [00:00, 126.88it/s]
# Running evaluation: 7it [00:00, 109.77it/s]
# Running evaluation: 7it [00:00, 122.26it/s]
# Running evaluation: 7it [00:00, 132.16it/s]
# Running evaluation: 7it [00:00, 134.98it/s]
# Running evaluation: 7it [00:00, 128.21it/s]
# Running evaluation: 7it [00:00, 128.63it/s]
# Running evaluation: 7it [00:00, 123.32it/s]
# Running evaluation: 7it [00:00, 127.79it/s]
# Running evaluation: 7it [00:00, 124.87it/s]
# Running evaluation: 7it [00:00, 128.81it/s]
# Running evaluation: 7it [00:00, 130.34it/s]
# Running evaluation: 7it [00:00, 128.75it/s]
# Running evaluation: 7it [00:00, 134.33it/s]
# Running evaluation: 7it [00:00, 128.54it/s]
# Running evaluation: 7it [00:00, 127.05it/s]
# Running evaluation: 7it [00:00, 129.76it/s]
# Running evaluation: 7it [00:00, 133.73it/s]
# Running evaluation: 7it [00:00, 127.12it/s]
# Running evaluation: 7it [00:00, 134.13it/s]
# Running evaluation: 7it [00:00, 126.47it/s]
# Running evaluation: 7it [00:00, 124.23it/s]
# Running evaluation: 7it [00:00, 130.68it/s]
# Running evaluation: 7it [00:00, 134.00it/s]
# Running evaluation: 7it [00:00, 128.65it/s]
# Running evaluation: 7it [00:00, 128.43it/s]
# Running evaluation: 7it [00:00, 125.29it/s]
# Running evaluation: 7it [00:00, 125.24it/s]
# Running evaluation: 7it [00:00, 124.52it/s]
# Running evaluation: 7it [00:00, 121.00it/s]
# Running evaluation: 7it [00:00, 134.65it/s]
# Running evaluation: 7it [00:00, 131.71it/s]
# Running evaluation: 7it [00:00, 131.51it/s]
# Running evaluation: 7it [00:00, 128.88it/s]
# Running evaluation: 7it [00:00, 128.38it/s]
# Running evaluation: 7it [00:00, 125.08it/s]
# Running evaluation: 7it [00:00, 126.04it/s]
# Running evaluation: 7it [00:00, 127.99it/s]
# Running evaluation: 7it [00:00, 123.65it/s]
# Running evaluation: 7it [00:00, 123.85it/s]
# Running evaluation: 7it [00:00, 137.23it/s]
# Running evaluation: 7it [00:00, 125.11it/s]
# Running evaluation: 7it [00:00, 128.37it/s]
# Running evaluation: 7it [00:00, 126.59it/s]
# Running evaluation: 7it [00:00, 129.31it/s]
# Running evaluation: 7it [00:00, 123.06it/s]
# Running evaluation: 7it [00:00, 130.71it/s]
# Running evaluation: 7it [00:00, 130.11it/s]
# Running evaluation: 7it [00:00, 126.39it/s]
# Running evaluation: 7it [00:00, 130.32it/s]
# Running evaluation: 7it [00:00, 133.63it/s]
# Running evaluation: 7it [00:00, 125.71it/s]
# Running evaluation: 7it [00:00, 134.39it/s]
# Running evaluation: 7it [00:00, 126.60it/s]
# Running evaluation: 7it [00:00, 133.53it/s]
# Running evaluation: 7it [00:00, 133.28it/s]
# Running evaluation: 7it [00:00, 133.60it/s]
# Running evaluation: 7it [00:00, 121.47it/s]
# Running evaluation: 7it [00:00, 124.88it/s]
# Running evaluation: 7it [00:00, 108.84it/s]
# Running evaluation: 7it [00:00, 127.72it/s]
# Running evaluation: 7it [00:00, 125.43it/s]
# Running evaluation: 7it [00:00, 129.13it/s]
# Running evaluation: 7it [00:00, 129.26it/s]
# Running evaluation: 7it [00:00, 129.35it/s]
# Running evaluation: 7it [00:00, 127.89it/s]
# Running evaluation: 7it [00:00, 124.59it/s]
# Running evaluation: 7it [00:00, 125.49it/s]
# Running evaluation: 7it [00:00, 128.04it/s]
# Running evaluation: 7it [00:00, 127.98it/s]
# Running evaluation: 7it [00:00, 132.22it/s]
# Running evaluation: 7it [00:00, 137.04it/s]
# Running evaluation: 7it [00:00, 132.76it/s]
# Running evaluation: 7it [00:00, 134.64it/s]
# Running evaluation: 7it [00:00, 131.40it/s]
# Running evaluation: 7it [00:00, 130.98it/s]
# Running evaluation: 7it [00:00, 128.31it/s]
# Running evaluation: 7it [00:00, 135.96it/s]
# Running evaluation: 7it [00:00, 128.95it/s]
# Running evaluation: 7it [00:00, 126.72it/s]
# Running evaluation: 7it [00:00, 131.24it/s]
# Running evaluation: 7it [00:00, 132.10it/s]
# Running evaluation: 7it [00:00, 134.11it/s]
# Running evaluation: 7it [00:00, 124.92it/s]
# Running evaluation: 7it [00:00, 124.73it/s]
# Running evaluation: 7it [00:00, 134.64it/s]
# Running evaluation: 7it [00:00, 135.42it/s]
# Running evaluation: 7it [00:00, 132.69it/s]
# Running evaluation: 7it [00:00, 133.15it/s]
# Running evaluation: 7it [00:00, 136.02it/s]
# Running evaluation: 7it [00:00, 123.23it/s]
# Running evaluation: 7it [00:00, 130.15it/s]
# Running evaluation: 7it [00:00, 133.08it/s]
# Running evaluation: 7it [00:00, 123.71it/s]
# Running evaluation: 7it [00:00, 135.27it/s]
# Running evaluation: 7it [00:00, 131.33it/s]
# Running evaluation: 7it [00:00, 128.37it/s]
# Running evaluation: 7it [00:00, 128.45it/s]
# Running evaluation: 7it [00:00, 124.56it/s]
# Running evaluation: 7it [00:00, 136.83it/s]
# Running evaluation: 7it [00:00, 129.80it/s]
# Running evaluation: 7it [00:00, 131.97it/s]
# Running evaluation: 7it [00:00, 132.02it/s]
# Running evaluation: 7it [00:00, 133.29it/s]
# Running evaluation: 7it [00:00, 131.10it/s]
# Running evaluation: 7it [00:00, 133.57it/s]
# Running evaluation: 7it [00:00, 133.96it/s]
# Running evaluation: 7it [00:00, 129.98it/s]
# Running evaluation: 7it [00:00, 113.61it/s]
# Running evaluation: 7it [00:00, 117.33it/s]
# Running evaluation: 7it [00:00, 125.38it/s]
# Running evaluation: 7it [00:00, 123.99it/s]
# Running evaluation: 7it [00:00, 133.35it/s]
# Running evaluation: 7it [00:00, 131.21it/s]
# Running evaluation: 7it [00:00, 128.76it/s]
# Running evaluation: 7it [00:00, 131.48it/s]
# Running evaluation: 7it [00:00, 126.55it/s]
# Running evaluation: 7it [00:00, 131.30it/s]
# Running evaluation: 7it [00:00, 136.53it/s]
# Running evaluation: 7it [00:00, 129.08it/s]
# Running evaluation: 7it [00:00, 131.74it/s]
# Running evaluation: 7it [00:00, 128.75it/s]
# Running evaluation: 7it [00:00, 128.24it/s]
# Running evaluation: 7it [00:00, 131.80it/s]
# Running evaluation: 7it [00:00, 128.74it/s]
# Running evaluation: 7it [00:00, 123.60it/s]
# Running evaluation: 7it [00:00, 134.19it/s]
# Running evaluation: 7it [00:00, 130.51it/s]
# Running evaluation: 7it [00:00, 130.98it/s]
# Running evaluation: 7it [00:00, 130.28it/s]
# Running evaluation: 7it [00:00, 124.15it/s]
# Running evaluation: 7it [00:00, 122.87it/s]
# Running evaluation: 7it [00:00, 133.97it/s]
# Running evaluation: 7it [00:00, 127.64it/s]
# Running evaluation: 7it [00:00, 121.94it/s]
# Running evaluation: 7it [00:00, 133.99it/s]
# Running evaluation: 7it [00:00, 127.86it/s]
# Running evaluation: 7it [00:00, 125.75it/s]
# Running evaluation: 7it [00:00, 124.86it/s]
# Running evaluation: 7it [00:00, 129.25it/s]
# Running evaluation: 7it [00:00, 134.16it/s]
# Running evaluation: 7it [00:00, 127.36it/s]
# Running evaluation: 7it [00:00, 130.72it/s]
# Running evaluation: 7it [00:00, 131.98it/s]
# Running evaluation: 7it [00:00, 129.57it/s]
# Running evaluation: 7it [00:00, 125.39it/s]
# Running evaluation: 7it [00:00, 135.03it/s]
# Running evaluation: 7it [00:00, 134.58it/s]
# Running evaluation: 7it [00:00, 130.36it/s]
# Running evaluation: 7it [00:00, 123.48it/s]
# Running evaluation: 7it [00:00, 136.14it/s]
# Running evaluation: 7it [00:00, 120.20it/s]
# Running evaluation: 7it [00:00, 130.80it/s]
# Running evaluation: 7it [00:00, 127.89it/s]
# Running evaluation: 7it [00:00, 130.78it/s]
# Running evaluation: 7it [00:00, 131.54it/s]
# Running evaluation: 7it [00:00, 118.47it/s]
# Running evaluation: 7it [00:00, 128.20it/s]
# Running evaluation: 7it [00:00, 125.92it/s]
# Running evaluation: 7it [00:00, 119.22it/s]
# Running evaluation: 7it [00:00, 120.45it/s]
# Running evaluation: 7it [00:00, 124.76it/s]
# Running evaluation: 7it [00:00, 127.91it/s]
# Running evaluation: 7it [00:00, 115.19it/s]
# Running evaluation: 7it [00:00, 124.50it/s]
# Running evaluation: 7it [00:00, 125.06it/s]
# Running evaluation: 7it [00:00, 118.75it/s]
# Running evaluation: 7it [00:00, 119.43it/s]
# Running evaluation: 7it [00:00, 125.52it/s]
# Running evaluation: 7it [00:00, 130.10it/s]
# Running evaluation: 7it [00:00, 124.81it/s]
# Running evaluation: 7it [00:00, 122.37it/s]
# Running evaluation: 7it [00:00, 136.65it/s]
# Running evaluation: 7it [00:00, 133.69it/s]
# Running evaluation: 7it [00:00, 132.78it/s]
# Running evaluation: 7it [00:00, 126.35it/s]
# Running evaluation: 7it [00:00, 130.86it/s]
# Running evaluation: 7it [00:00, 136.34it/s]
# Running evaluation: 7it [00:00, 113.25it/s]
# Running evaluation: 7it [00:00, 124.23it/s]
# Running evaluation: 7it [00:00, 128.40it/s]
# Running evaluation: 7it [00:00, 134.05it/s]
# Running evaluation: 7it [00:00, 128.84it/s]
# Running evaluation: 7it [00:00, 129.83it/s]
# Running evaluation: 7it [00:00, 122.39it/s]
# Running evaluation: 7it [00:00, 132.59it/s]
# Running evaluation: 7it [00:00, 123.65it/s]
# Running evaluation: 7it [00:00, 133.57it/s]
# Running evaluation: 7it [00:00, 126.22it/s]
# Running evaluation: 7it [00:00, 126.24it/s]
# Running evaluation: 7it [00:00, 124.85it/s]
# Running evaluation: 7it [00:00, 128.78it/s]
# Running evaluation: 7it [00:00, 130.88it/s]
# Running evaluation: 7it [00:00, 130.77it/s]
# Running evaluation: 7it [00:00, 125.32it/s]
# Running evaluation: 7it [00:00, 128.58it/s]
# Running evaluation: 7it [00:00, 132.69it/s]
# Running evaluation: 7it [00:00, 130.01it/s]
# Running evaluation: 7it [00:00, 132.02it/s]
# Running evaluation: 7it [00:00, 130.90it/s]
# Running evaluation: 7it [00:00, 127.86it/s]
# Running evaluation: 7it [00:00, 116.76it/s]
# Running evaluation: 7it [00:00, 126.17it/s]
# Running evaluation: 7it [00:00, 129.31it/s]
# Running evaluation: 7it [00:00, 130.26it/s]
# Running evaluation: 7it [00:00, 127.43it/s]
# Running evaluation: 7it [00:00, 123.33it/s]
# Running evaluation: 7it [00:00, 124.64it/s]
# Running evaluation: 7it [00:00, 136.76it/s]
# Running evaluation: 7it [00:00, 133.21it/s]
# Running evaluation: 7it [00:00, 135.54it/s]
# Running evaluation: 7it [00:00, 127.29it/s]
# Running evaluation: 7it [00:00, 134.72it/s]
# Running evaluation: 7it [00:00, 129.16it/s]
# Running evaluation: 7it [00:00, 131.28it/s]
# Running evaluation: 7it [00:00, 128.74it/s]
# Running evaluation: 7it [00:00, 129.82it/s]
# Running evaluation: 7it [00:00, 129.78it/s]
# Running evaluation: 7it [00:00, 123.59it/s]
# Running evaluation: 7it [00:00, 132.93it/s]
# Running evaluation: 7it [00:00, 125.75it/s]
# Running evaluation: 7it [00:00, 126.02it/s]
# Running evaluation: 7it [00:00, 120.79it/s]
# Running evaluation: 7it [00:00, 130.10it/s]
# Running evaluation: 7it [00:00, 130.34it/s]
# Running evaluation: 7it [00:00, 127.24it/s]
# Running evaluation: 7it [00:00, 131.28it/s]
# Running evaluation: 7it [00:00, 127.78it/s]
# Running evaluation: 7it [00:00, 135.97it/s]
# Running evaluation: 7it [00:00, 130.65it/s]
# Running evaluation: 7it [00:00, 130.13it/s]
# Running evaluation: 7it [00:00, 127.24it/s]
# Running evaluation: 7it [00:00, 134.04it/s]
# Running evaluation: 7it [00:00, 124.49it/s]
# Running evaluation: 7it [00:00, 111.70it/s]
# Running evaluation: 7it [00:00, 113.65it/s]
# Running evaluation: 7it [00:00, 115.38it/s]
# Running evaluation: 7it [00:00, 122.91it/s]
# Running evaluation: 7it [00:00, 122.97it/s]
# Running evaluation: 7it [00:00, 121.45it/s]
# Running evaluation: 7it [00:00, 117.48it/s]
# Running evaluation: 7it [00:00, 124.51it/s]
# Running evaluation: 7it [00:00, 106.28it/s]
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1097: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gluonts/evaluation/_base.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   totals["NRMSE"] = totals["RMSE"] / totals["abs_target_mean"]
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gluonts/evaluation/_base.py:532: RuntimeWarning: divide by zero encountered in double_scalars
#   totals["ND"] = totals["abs_error"] / totals["abs_target_sum"]
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gluonts/evaluation/_base.py:536: RuntimeWarning: divide by zero encountered in double_scalars
#   totals[f"QuantileLoss[{quantile}]"] / totals["abs_target_sum"]
# Running evaluation: 7it [00:00, 127.60it/s]
# Running evaluation: 7it [00:00, 125.51it/s]
# Running evaluation: 7it [00:00, 126.45it/s]
# Running evaluation: 7it [00:00, 123.99it/s]
# Running evaluation: 7it [00:00, 120.95it/s]
# Running evaluation: 7it [00:00, 108.48it/s]
# Running evaluation: 7it [00:00, 114.20it/s]
# Running evaluation: 7it [00:00, 114.64it/s]
# Running evaluation: 7it [00:00, 119.10it/s]
# Running evaluation: 7it [00:00, 123.83it/s]
# Running evaluation: 7it [00:00, 122.48it/s]
# Running evaluation: 7it [00:00, 128.24it/s]
# Running evaluation: 7it [00:00, 121.96it/s]
# Running evaluation: 7it [00:00, 130.76it/s]
# Running evaluation: 7it [00:00, 127.90it/s]
# Running evaluation: 7it [00:00, 129.17it/s]
# Running evaluation: 7it [00:00, 129.63it/s]
# Running evaluation: 7it [00:00, 134.45it/s]
# Running evaluation: 7it [00:00, 110.77it/s]
# Running evaluation: 7it [00:00, 128.65it/s]
# Running evaluation: 7it [00:00, 126.91it/s]
# Running evaluation: 7it [00:00, 124.30it/s]
# Running evaluation: 7it [00:00, 126.20it/s]
# Running evaluation: 7it [00:00, 131.83it/s]
# Running evaluation: 7it [00:00, 122.22it/s]
# Running evaluation: 7it [00:00, 125.09it/s]
# Running evaluation: 7it [00:00, 122.01it/s]
# Running evaluation: 7it [00:00, 128.52it/s]
# Running evaluation: 7it [00:00, 122.30it/s]
# Running evaluation: 7it [00:00, 125.17it/s]
# Running evaluation: 7it [00:00, 127.69it/s]
# Running evaluation: 7it [00:00, 124.64it/s]
# Running evaluation: 7it [00:00, 128.23it/s]
# Running evaluation: 7it [00:00, 122.42it/s]
# Running evaluation: 7it [00:00, 121.54it/s]
# Running evaluation: 7it [00:00, 116.45it/s]
# Running evaluation: 7it [00:00, 123.23it/s]
# Running evaluation: 7it [00:00, 112.82it/s]
# Running evaluation: 7it [00:00, 112.54it/s]
# Running evaluation: 7it [00:00, 123.42it/s]
# Running evaluation: 7it [00:00, 111.87it/s]
# Running evaluation: 7it [00:00, 116.31it/s]
# Running evaluation: 7it [00:00, 122.68it/s]
# Running evaluation: 7it [00:00, 127.38it/s]
# Running evaluation: 7it [00:00, 128.28it/s]
# Running evaluation: 7it [00:00, 128.00it/s]
# Running evaluation: 7it [00:00, 128.43it/s]
# Running evaluation: 7it [00:00, 62.31it/s]

# %%
print("CRPS:", agg_metric["mean_wQuantileLoss"])
print("ND:", agg_metric["ND"])
print("NRMSE:", agg_metric["NRMSE"])
print("")
print("CRPS-Sum:", agg_metric["m_sum_mean_wQuantileLoss"])
print("ND-Sum:", agg_metric["m_sum_ND"])
print("NRMSE-Sum:", agg_metric["m_sum_NRMSE"])
# Out:
# CRPS: 0.07029951728012702
# ND: 0.08983447565530381
# NRMSE: 0.9683772738542332
#
# CRPS-Sum: 0.04390423835448947
# ND-Sum: 0.05801630636090176
# NRMSE-Sum: 0.08792091112696589
