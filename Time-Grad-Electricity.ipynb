# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

import torch

# %%
from gluonts.dataset.multivariate_grouper import MultivariateGrouper
from gluonts.dataset.repository.datasets import dataset_recipes, get_dataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import MultivariateEvaluator

# %%
# from pts.model.tempflow import TempFlowEstimator
from pts.model.time_grad import TimeGradEstimator
# from pts.model.transformer_tempflow import TransformerTempFlowEstimator
# from pts import Trainer
from pytorch_lightning import Trainer

# %%
from diffusers import (
    PNDMScheduler,
    DDIMScheduler,
    DPMSolverMultistepScheduler,
    KDPM2DiscreteScheduler,
    DEISMultistepScheduler,
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def plot(target, forecast, prediction_length, prediction_intervals=(50.0, 90.0), color='g', fname=None):
    label_prefix = ""
    rows = 4
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize=(24, 24))
    axx = axs.ravel()
    seq_len, target_dim = target.shape
    
    ps = [50.0] + [
            50.0 + f * c / 2.0 for c in prediction_intervals for f in [-1.0, +1.0]
        ]
        
    percentiles_sorted = sorted(set(ps))
    
    def alpha_for_percentile(p):
        return (p / 100.0) ** 0.3
        
    for dim in range(0, min(rows * cols, target_dim)):
        ax = axx[dim]

        target[-2 * prediction_length :][dim].plot(ax=ax)
        
        ps_data = [forecast.quantile(p / 100.0)[:,dim] for p in percentiles_sorted]
        i_p50 = len(percentiles_sorted) // 2
        
        p50_data = ps_data[i_p50]
        p50_series = pd.Series(data=p50_data, index=forecast.index)
        p50_series.plot(color=color, ls="-", label=f"{label_prefix}median", ax=ax)
        
        for i in range(len(percentiles_sorted) // 2):
            ptile = percentiles_sorted[i]
            alpha = alpha_for_percentile(ptile)
            ax.fill_between(
                forecast.index,
                ps_data[i],
                ps_data[-i - 1],
                facecolor=color,
                alpha=alpha,
                interpolate=True,
            )
            # Hack to create labels for the error intervals.
            # Doesn't actually plot anything, because we only pass a single data point
            pd.Series(data=p50_data[:1], index=forecast.index[:1]).plot(
                color=color,
                alpha=alpha,
                linewidth=10,
                label=f"{label_prefix}{100 - ptile * 2}%",
                ax=ax,
            )

    legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1]    
    axx[0].legend(legend, loc="upper left")
    
    if fname is not None:
        plt.savefig(fname, bbox_inches='tight', pad_inches=0.05)

# %%
print(f"Available datasets: {list(dataset_recipes.keys())}")
# Out:
# Available datasets: ['constant', 'exchange_rate', 'solar-energy', 'electricity', 'traffic', 'exchange_rate_nips', 'electricity_nips', 'traffic_nips', 'solar_nips', 'wiki2000_nips', 'wiki-rolling_nips', 'taxi_30min', 'kaggle_web_traffic_with_missing', 'kaggle_web_traffic_without_missing', 'kaggle_web_traffic_weekly', 'm1_yearly', 'm1_quarterly', 'm1_monthly', 'nn5_daily_with_missing', 'nn5_daily_without_missing', 'nn5_weekly', 'tourism_monthly', 'tourism_quarterly', 'tourism_yearly', 'cif_2016', 'london_smart_meters_without_missing', 'wind_farms_without_missing', 'car_parts_without_missing', 'dominick', 'fred_md', 'pedestrian_counts', 'hospital', 'covid_deaths', 'kdd_cup_2018_without_missing', 'weather', 'm3_monthly', 'm3_quarterly', 'm3_yearly', 'm3_other', 'm4_hourly', 'm4_daily', 'm4_weekly', 'm4_monthly', 'm4_quarterly', 'm4_yearly', 'm5', 'uber_tlc_daily', 'uber_tlc_hourly', 'airpassengers', 'australian_electricity_demand', 'electricity_hourly', 'electricity_weekly', 'rideshare_without_missing', 'saugeenday', 'solar_10_minutes', 'solar_weekly', 'sunspot_without_missing', 'temperature_rain_without_missing', 'vehicle_trips_without_missing']

# %%
# exchange_rate_nips, electricity_nips, traffic_nips, solar_nips, wiki-rolling_nips, ## taxi_30min is buggy still
dataset = get_dataset("electricity_nips", regenerate=False)

# %%
dataset.metadata
# Out:
# MetaData(freq='H', target=None, feat_static_cat=[CategoricalFeatureInfo(name='feat_static_cat_0', cardinality='370')], feat_static_real=[], feat_dynamic_real=[], feat_dynamic_cat=[], prediction_length=24)

# %%
train_grouper = MultivariateGrouper(max_target_dim=min(2000, int(dataset.metadata.feat_static_cat[0].cardinality)))

test_grouper = MultivariateGrouper(num_test_dates=int(len(dataset.test)/len(dataset.train)), 
                                   max_target_dim=min(2000, int(dataset.metadata.feat_static_cat[0].cardinality)))

# %%
dataset_train = train_grouper(dataset.train)
dataset_test = test_grouper(dataset.test)

# %%
scheduler = DEISMultistepScheduler(
    num_train_timesteps=150,
    beta_end=0.1,
)

# %%
estimator = TimeGradEstimator(
    input_size=int(dataset.metadata.feat_static_cat[0].cardinality),
    hidden_size=64,
    num_layers=2,
    dropout_rate=0.1,
    lags_seq=[1],
    scheduler=scheduler,
    num_inference_steps=149,
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length * 3,
    freq=dataset.metadata.freq,
    scaling="mean",
    trainer_kwargs=dict(max_epochs=20, devices="1"),
)

# %%
predictor = estimator.train(dataset_train, num_workers=8)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name  | Type          | Params | In sizes | Out sizes
# -----------------------------------------------------------------------
# 0 | model | TimeGradModel | 432 K  | ?        | [1, 100, 24, 370]
# -----------------------------------------------------------------------
# 432 K     Trainable params
# 0         Non-trainable params
# 432 K     Total params
# 1.729     Total estimated model params size (MB)
# Training: |          | 0/? [00:00<?, ?it/s]
# Epoch 0, global step 50: 'train_loss' reached 0.34740 (best 0.34740), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 0.09696 (best 0.09696), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 0.06702 (best 0.06702), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 0.05679 (best 0.05679), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 0.05101 (best 0.05101), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' reached 0.04600 (best 0.04600), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=5-step=300.ckpt' as top 1
# Epoch 6, global step 350: 'train_loss' reached 0.04439 (best 0.04439), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' reached 0.04319 (best 0.04319), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' reached 0.04261 (best 0.04261), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=8-step=450.ckpt' as top 1
# Epoch 9, global step 500: 'train_loss' reached 0.04150 (best 0.04150), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' was not in top 1
# Epoch 11, global step 600: 'train_loss' reached 0.03974 (best 0.03974), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=11-step=600.ckpt' as top 1
# Epoch 12, global step 650: 'train_loss' reached 0.03868 (best 0.03868), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=12-step=650.ckpt' as top 1
# Epoch 13, global step 700: 'train_loss' reached 0.03803 (best 0.03803), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=13-step=700.ckpt' as top 1
# Epoch 14, global step 750: 'train_loss' reached 0.03704 (best 0.03704), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=14-step=750.ckpt' as top 1
# Epoch 15, global step 800: 'train_loss' reached 0.03684 (best 0.03684), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=15-step=800.ckpt' as top 1
# Epoch 16, global step 850: 'train_loss' was not in top 1
# Epoch 17, global step 900: 'train_loss' reached 0.03618 (best 0.03618), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=17-step=900.ckpt' as top 1
# Epoch 18, global step 950: 'train_loss' reached 0.03600 (best 0.03600), saving model to '/Users/kwunyingzhou/timegrad-s4/lightning_logs/version_1/checkpoints/epoch=18-step=950.ckpt' as top 1
# Epoch 19, global step 1000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=20` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(dataset=dataset_test,
                                                 predictor=predictor,
                                                 num_samples=100)

# %%
forecasts = list(forecast_it)
targets = list(ts_it)

# %%
plot(
    target=targets[0],
    forecast=forecasts[0],
    prediction_length=dataset.metadata.prediction_length,
)
plt.show()

# %%
evaluator = MultivariateEvaluator(quantiles=(np.arange(20)/20.0)[1:], 
                                  target_agg_funcs={'sum': np.sum})

# %%
agg_metric, item_metrics = evaluator(targets, forecasts, num_series=len(dataset_test))
# Out:
# Running evaluation: 7it [00:00, 89.81it/s]
# Running evaluation: 7it [00:00, 129.00it/s]
# Running evaluation: 7it [00:00, 119.02it/s]
# Running evaluation: 7it [00:00, 125.62it/s]
# Running evaluation: 7it [00:00, 125.28it/s]
# Running evaluation: 7it [00:00, 123.69it/s]
# Running evaluation: 7it [00:00, 121.32it/s]
# Running evaluation: 7it [00:00, 126.78it/s]
# Running evaluation: 7it [00:00, 119.29it/s]
# Running evaluation: 7it [00:00, 118.75it/s]
# Running evaluation: 7it [00:00, 126.88it/s]
# Running evaluation: 7it [00:00, 126.68it/s]
# Running evaluation: 7it [00:00, 110.98it/s]
# Running evaluation: 7it [00:00, 94.15it/s]
# Running evaluation: 7it [00:00, 90.58it/s]
# Running evaluation: 7it [00:00, 110.22it/s]
# Running evaluation: 7it [00:00, 122.76it/s]
# Running evaluation: 7it [00:00, 117.24it/s]
# Running evaluation: 7it [00:00, 123.43it/s]
# Running evaluation: 7it [00:00, 120.28it/s]
# Running evaluation: 7it [00:00, 126.66it/s]
# Running evaluation: 7it [00:00, 119.65it/s]
# Running evaluation: 7it [00:00, 114.55it/s]
# Running evaluation: 7it [00:00, 117.11it/s]
# Running evaluation: 7it [00:00, 97.50it/s]
# Running evaluation: 7it [00:00, 101.40it/s]
# Running evaluation: 7it [00:00, 121.59it/s]
# Running evaluation: 7it [00:00, 120.77it/s]
# Running evaluation: 7it [00:00, 108.04it/s]
# Running evaluation: 7it [00:00, 115.19it/s]
# Running evaluation: 7it [00:00, 118.83it/s]
# Running evaluation: 7it [00:00, 117.71it/s]
# Running evaluation: 7it [00:00, 112.31it/s]
# Running evaluation: 7it [00:00, 115.74it/s]
# Running evaluation: 7it [00:00, 109.04it/s]
# Running evaluation: 7it [00:00, 109.57it/s]
# Running evaluation: 7it [00:00, 120.41it/s]
# Running evaluation: 7it [00:00, 118.82it/s]
# Running evaluation: 7it [00:00, 125.04it/s]
# Running evaluation: 7it [00:00, 122.19it/s]
# Running evaluation: 7it [00:00, 123.12it/s]
# Running evaluation: 7it [00:00, 126.61it/s]
# Running evaluation: 7it [00:00, 125.47it/s]
# Running evaluation: 7it [00:00, 124.77it/s]
# Running evaluation: 7it [00:00, 122.06it/s]
# Running evaluation: 7it [00:00, 123.33it/s]
# Running evaluation: 7it [00:00, 122.96it/s]
# Running evaluation: 7it [00:00, 119.18it/s]
# Running evaluation: 7it [00:00, 121.69it/s]
# Running evaluation: 7it [00:00, 125.78it/s]
# Running evaluation: 7it [00:00, 125.19it/s]
# Running evaluation: 7it [00:00, 121.84it/s]
# Running evaluation: 7it [00:00, 123.59it/s]
# Running evaluation: 7it [00:00, 113.99it/s]
# Running evaluation: 7it [00:00, 127.95it/s]
# Running evaluation: 7it [00:00, 123.85it/s]
# Running evaluation: 7it [00:00, 75.26it/s]
# Running evaluation: 7it [00:00, 119.34it/s]
# Running evaluation: 7it [00:00, 123.90it/s]
# Running evaluation: 7it [00:00, 125.74it/s]
# Running evaluation: 7it [00:00, 124.01it/s]
# Running evaluation: 7it [00:00, 120.34it/s]
# Running evaluation: 7it [00:00, 131.02it/s]
# Running evaluation: 7it [00:00, 120.16it/s]
# Running evaluation: 7it [00:00, 116.78it/s]
# Running evaluation: 7it [00:00, 117.67it/s]
# Running evaluation: 7it [00:00, 125.79it/s]
# Running evaluation: 7it [00:00, 97.11it/s]
# Running evaluation: 7it [00:00, 106.58it/s]
# Running evaluation: 7it [00:00, 98.44it/s]
# Running evaluation: 7it [00:00, 107.86it/s]
# Running evaluation: 7it [00:00, 109.08it/s]
# Running evaluation: 7it [00:00, 111.61it/s]
# Running evaluation: 7it [00:00, 86.47it/s]
# Running evaluation: 7it [00:00, 89.18it/s]
# Running evaluation: 7it [00:00, 110.71it/s]
# Running evaluation: 7it [00:00, 107.60it/s]
# Running evaluation: 7it [00:00, 111.93it/s]
# Running evaluation: 7it [00:00, 102.84it/s]
# Running evaluation: 7it [00:00, 119.34it/s]
# Running evaluation: 7it [00:00, 105.23it/s]
# Running evaluation: 7it [00:00, 123.30it/s]
# Running evaluation: 7it [00:00, 123.03it/s]
# Running evaluation: 7it [00:00, 105.29it/s]
# Running evaluation: 7it [00:00, 79.49it/s]
# Running evaluation: 7it [00:00, 77.06it/s]
# Running evaluation: 7it [00:00, 99.78it/s]
# Running evaluation: 7it [00:00, 90.54it/s]
# Running evaluation: 7it [00:00, 110.92it/s]
# Running evaluation: 7it [00:00, 119.42it/s]
# Running evaluation: 7it [00:00, 119.38it/s]
# Running evaluation: 7it [00:00, 118.67it/s]
# Running evaluation: 7it [00:00, 100.17it/s]
# Running evaluation: 7it [00:00, 105.05it/s]
# Running evaluation: 7it [00:00, 112.67it/s]
# Running evaluation: 7it [00:00, 98.82it/s]
# Running evaluation: 7it [00:00, 109.15it/s]
# Running evaluation: 7it [00:00, 114.23it/s]
# Running evaluation: 7it [00:00, 115.91it/s]
# Running evaluation: 7it [00:00, 113.57it/s]
# Running evaluation: 7it [00:00, 115.90it/s]
# Running evaluation: 7it [00:00, 116.75it/s]
# Running evaluation: 7it [00:00, 124.51it/s]
# Running evaluation: 7it [00:00, 120.40it/s]
# Running evaluation: 7it [00:00, 117.99it/s]
# Running evaluation: 7it [00:00, 116.40it/s]
# Running evaluation: 7it [00:00, 111.04it/s]
# Running evaluation: 7it [00:00, 107.40it/s]
# Running evaluation: 7it [00:00, 116.91it/s]
# Running evaluation: 7it [00:00, 111.03it/s]
# Running evaluation: 7it [00:00, 110.24it/s]
# Running evaluation: 7it [00:00, 110.46it/s]
# Running evaluation: 7it [00:00, 117.90it/s]
# Running evaluation: 7it [00:00, 28.38it/s]
# Running evaluation: 7it [00:00, 108.07it/s]
# Running evaluation: 7it [00:00, 119.70it/s]
# Running evaluation: 7it [00:00, 118.96it/s]
# Running evaluation: 7it [00:00, 122.34it/s]
# Running evaluation: 7it [00:00, 48.75it/s]
# Running evaluation: 7it [00:00, 94.81it/s]
# Running evaluation: 7it [00:00, 107.23it/s]
# Running evaluation: 7it [00:00, 71.55it/s]
# Running evaluation: 7it [00:00, 55.74it/s]
# Running evaluation: 7it [00:00, 118.52it/s]
# Running evaluation: 7it [00:00, 115.05it/s]
# Running evaluation: 7it [00:00, 107.07it/s]
# Running evaluation: 7it [00:00, 85.16it/s]
# Running evaluation: 7it [00:00, 93.41it/s]
# Running evaluation: 7it [00:00, 106.89it/s]
# Running evaluation: 7it [00:00, 111.55it/s]
# Running evaluation: 7it [00:00, 118.07it/s]
# Running evaluation: 7it [00:00, 108.65it/s]
# Running evaluation: 7it [00:00, 94.34it/s]
# Running evaluation: 7it [00:00, 109.80it/s]
# Running evaluation: 7it [00:00, 109.46it/s]
# Running evaluation: 7it [00:00, 114.49it/s]
# Running evaluation: 7it [00:00, 116.57it/s]
# Running evaluation: 7it [00:00, 119.09it/s]
# Running evaluation: 7it [00:00, 116.93it/s]
# Running evaluation: 7it [00:00, 122.06it/s]
# Running evaluation: 7it [00:00, 115.95it/s]
# Running evaluation: 7it [00:00, 92.49it/s]
# Running evaluation: 7it [00:00, 119.47it/s]
# Running evaluation: 7it [00:00, 120.63it/s]
# Running evaluation: 7it [00:00, 120.84it/s]
# Running evaluation: 7it [00:00, 125.18it/s]
# Running evaluation: 7it [00:00, 113.49it/s]
# Running evaluation: 7it [00:00, 115.18it/s]
# Running evaluation: 7it [00:00, 119.55it/s]
# Running evaluation: 7it [00:00, 102.25it/s]
# Running evaluation: 7it [00:00, 114.76it/s]
# Running evaluation: 7it [00:00, 114.71it/s]
# Running evaluation: 7it [00:00, 122.57it/s]
# Running evaluation: 7it [00:00, 118.70it/s]
# Running evaluation: 7it [00:00, 124.73it/s]
# Running evaluation: 7it [00:00, 118.37it/s]
# Running evaluation: 7it [00:00, 119.02it/s]
# Running evaluation: 7it [00:00, 120.17it/s]
# Running evaluation: 7it [00:00, 122.08it/s]
# Running evaluation: 7it [00:00, 117.70it/s]
# Running evaluation: 7it [00:00, 111.55it/s]
# Running evaluation: 7it [00:00, 103.32it/s]
# Running evaluation: 7it [00:00, 112.42it/s]
# Running evaluation: 7it [00:00, 116.09it/s]
# Running evaluation: 7it [00:00, 110.98it/s]
# Running evaluation: 7it [00:00, 115.12it/s]
# Running evaluation: 7it [00:00, 111.18it/s]
# Running evaluation: 7it [00:00, 106.83it/s]
# Running evaluation: 7it [00:00, 113.38it/s]
# Running evaluation: 7it [00:00, 116.17it/s]
# Running evaluation: 7it [00:00, 51.74it/s]
# Running evaluation: 7it [00:00, 109.42it/s]
# Running evaluation: 7it [00:00, 112.87it/s]
# Running evaluation: 7it [00:00, 111.57it/s]
# Running evaluation: 7it [00:00, 109.95it/s]
# Running evaluation: 7it [00:00, 109.97it/s]
# Running evaluation: 7it [00:00, 115.40it/s]
# Running evaluation: 7it [00:00, 122.75it/s]
# Running evaluation: 7it [00:00, 124.14it/s]
# Running evaluation: 7it [00:00, 120.12it/s]
# Running evaluation: 7it [00:00, 112.27it/s]
# Running evaluation: 7it [00:00, 113.01it/s]
# Running evaluation: 7it [00:00, 125.39it/s]
# Running evaluation: 7it [00:00, 112.77it/s]
# Running evaluation: 7it [00:00, 121.87it/s]
# Running evaluation: 7it [00:00, 117.47it/s]
# Running evaluation: 7it [00:00, 101.70it/s]
# Running evaluation: 7it [00:00, 120.00it/s]
# Running evaluation: 7it [00:00, 121.43it/s]
# Running evaluation: 7it [00:00, 120.66it/s]
# Running evaluation: 7it [00:00, 118.05it/s]
# Running evaluation: 7it [00:00, 118.33it/s]
# Running evaluation: 7it [00:00, 110.78it/s]
# Running evaluation: 7it [00:00, 114.68it/s]
# Running evaluation: 7it [00:00, 116.20it/s]
# Running evaluation: 7it [00:00, 123.35it/s]
# Running evaluation: 7it [00:00, 121.79it/s]
# Running evaluation: 7it [00:00, 94.84it/s]
# Running evaluation: 7it [00:00, 121.53it/s]
# Running evaluation: 7it [00:00, 116.51it/s]
# Running evaluation: 7it [00:00, 113.05it/s]
# Running evaluation: 7it [00:00, 116.70it/s]
# Running evaluation: 7it [00:00, 125.43it/s]
# Running evaluation: 7it [00:00, 118.07it/s]
# Running evaluation: 7it [00:00, 119.72it/s]
# Running evaluation: 7it [00:00, 125.75it/s]
# Running evaluation: 7it [00:00, 120.55it/s]
# Running evaluation: 7it [00:00, 122.11it/s]
# Running evaluation: 7it [00:00, 121.33it/s]
# Running evaluation: 7it [00:00, 125.61it/s]
# Running evaluation: 7it [00:00, 120.91it/s]
# Running evaluation: 7it [00:00, 114.54it/s]
# Running evaluation: 7it [00:00, 120.03it/s]
# Running evaluation: 7it [00:00, 118.40it/s]
# Running evaluation: 7it [00:00, 123.66it/s]
# Running evaluation: 7it [00:00, 110.49it/s]
# Running evaluation: 7it [00:00, 113.65it/s]
# Running evaluation: 7it [00:00, 127.59it/s]
# Running evaluation: 7it [00:00, 128.03it/s]
# Running evaluation: 7it [00:00, 124.02it/s]
# Running evaluation: 7it [00:00, 119.53it/s]
# Running evaluation: 7it [00:00, 120.97it/s]
# Running evaluation: 7it [00:00, 120.27it/s]
# Running evaluation: 7it [00:00, 122.72it/s]
# Running evaluation: 7it [00:00, 122.81it/s]
# Running evaluation: 7it [00:00, 123.03it/s]
# Running evaluation: 7it [00:00, 120.65it/s]
# Running evaluation: 7it [00:00, 122.16it/s]
# Running evaluation: 7it [00:00, 125.04it/s]
# Running evaluation: 7it [00:00, 122.05it/s]
# Running evaluation: 7it [00:00, 117.46it/s]
# Running evaluation: 7it [00:00, 114.77it/s]
# Running evaluation: 7it [00:00, 113.53it/s]
# Running evaluation: 7it [00:00, 118.08it/s]
# Running evaluation: 7it [00:00, 121.71it/s]
# Running evaluation: 7it [00:00, 116.67it/s]
# Running evaluation: 7it [00:00, 123.12it/s]
# Running evaluation: 7it [00:00, 127.49it/s]
# Running evaluation: 7it [00:00, 126.67it/s]
# Running evaluation: 7it [00:00, 117.60it/s]
# Running evaluation: 7it [00:00, 121.31it/s]
# Running evaluation: 7it [00:00, 109.13it/s]
# Running evaluation: 7it [00:00, 128.44it/s]
# Running evaluation: 7it [00:00, 130.73it/s]
# Running evaluation: 7it [00:00, 134.41it/s]
# Running evaluation: 7it [00:00, 122.91it/s]
# Running evaluation: 7it [00:00, 125.10it/s]
# Running evaluation: 7it [00:00, 126.99it/s]
# Running evaluation: 7it [00:00, 130.91it/s]
# Running evaluation: 7it [00:00, 114.40it/s]
# Running evaluation: 7it [00:00, 113.63it/s]
# Running evaluation: 7it [00:00, 112.30it/s]
# Running evaluation: 7it [00:00, 116.62it/s]
# Running evaluation: 7it [00:00, 123.38it/s]
# Running evaluation: 7it [00:00, 125.84it/s]
# Running evaluation: 7it [00:00, 124.64it/s]
# Running evaluation: 7it [00:00, 117.15it/s]
# Running evaluation: 7it [00:00, 121.94it/s]
# Running evaluation: 7it [00:00, 118.67it/s]
# Running evaluation: 7it [00:00, 122.09it/s]
# Running evaluation: 7it [00:00, 118.26it/s]
# Running evaluation: 7it [00:00, 128.80it/s]
# Running evaluation: 7it [00:00, 123.66it/s]
# Running evaluation: 7it [00:00, 120.98it/s]
# Running evaluation: 7it [00:00, 122.81it/s]
# Running evaluation: 7it [00:00, 119.30it/s]
# Running evaluation: 7it [00:00, 120.07it/s]
# Running evaluation: 7it [00:00, 120.46it/s]
# Running evaluation: 7it [00:00, 111.72it/s]
# Running evaluation: 7it [00:00, 124.10it/s]
# Running evaluation: 7it [00:00, 120.05it/s]
# Running evaluation: 7it [00:00, 125.41it/s]
# Running evaluation: 7it [00:00, 123.71it/s]
# Running evaluation: 7it [00:00, 131.37it/s]
# Running evaluation: 7it [00:00, 121.23it/s]
# Running evaluation: 7it [00:00, 119.60it/s]
# Running evaluation: 7it [00:00, 124.70it/s]
# Running evaluation: 7it [00:00, 120.72it/s]
# Running evaluation: 7it [00:00, 123.16it/s]
# Running evaluation: 7it [00:00, 122.05it/s]
# Running evaluation: 7it [00:00, 125.06it/s]
# Running evaluation: 7it [00:00, 122.82it/s]
# Running evaluation: 7it [00:00, 118.90it/s]
# Running evaluation: 7it [00:00, 127.32it/s]
# Running evaluation: 7it [00:00, 121.69it/s]
# Running evaluation: 7it [00:00, 124.13it/s]
# Running evaluation: 7it [00:00, 121.44it/s]
# Running evaluation: 7it [00:00, 122.54it/s]
# Running evaluation: 7it [00:00, 118.50it/s]
# Running evaluation: 7it [00:00, 113.78it/s]
# Running evaluation: 7it [00:00, 94.53it/s]
# Running evaluation: 7it [00:00, 113.24it/s]
# Running evaluation: 7it [00:00, 123.34it/s]
# Running evaluation: 7it [00:00, 121.14it/s]
# Running evaluation: 7it [00:00, 123.62it/s]
# Running evaluation: 7it [00:00, 122.79it/s]
# Running evaluation: 7it [00:00, 119.73it/s]
# Running evaluation: 7it [00:00, 124.00it/s]
# Running evaluation: 7it [00:00, 109.46it/s]
# Running evaluation: 7it [00:00, 114.15it/s]
# Running evaluation: 7it [00:00, 118.35it/s]
# Running evaluation: 7it [00:00, 113.23it/s]
# Running evaluation: 7it [00:00, 121.11it/s]
# Running evaluation: 7it [00:00, 127.88it/s]
# Running evaluation: 7it [00:00, 126.31it/s]
# Running evaluation: 7it [00:00, 128.53it/s]
# Running evaluation: 7it [00:00, 124.32it/s]
# Running evaluation: 7it [00:00, 130.13it/s]
# Running evaluation: 7it [00:00, 125.90it/s]
# Running evaluation: 7it [00:00, 124.01it/s]
# Running evaluation: 7it [00:00, 116.23it/s]
# Running evaluation: 7it [00:00, 103.74it/s]
# Running evaluation: 7it [00:00, 111.69it/s]
# Running evaluation: 7it [00:00, 112.67it/s]
# Running evaluation: 7it [00:00, 121.72it/s]
# Running evaluation: 7it [00:00, 123.50it/s]
# Running evaluation: 7it [00:00, 122.88it/s]
# Running evaluation: 7it [00:00, 123.38it/s]
# Running evaluation: 7it [00:00, 128.52it/s]
# Running evaluation: 7it [00:00, 118.23it/s]
# Running evaluation: 7it [00:00, 119.73it/s]
# Running evaluation: 7it [00:00, 121.86it/s]
# Running evaluation: 7it [00:00, 123.14it/s]
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1097: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gluonts/evaluation/_base.py:531: RuntimeWarning: divide by zero encountered in double_scalars
#   totals["NRMSE"] = totals["RMSE"] / totals["abs_target_mean"]
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gluonts/evaluation/_base.py:532: RuntimeWarning: divide by zero encountered in double_scalars
#   totals["ND"] = totals["abs_error"] / totals["abs_target_sum"]
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/gluonts/evaluation/_base.py:536: RuntimeWarning: divide by zero encountered in double_scalars
#   totals[f"QuantileLoss[{quantile}]"] / totals["abs_target_sum"]
# Running evaluation: 7it [00:00, 119.87it/s]
# Running evaluation: 7it [00:00, 117.54it/s]
# Running evaluation: 7it [00:00, 105.91it/s]
# Running evaluation: 7it [00:00, 112.07it/s]
# Running evaluation: 7it [00:00, 118.00it/s]
# Running evaluation: 7it [00:00, 118.55it/s]
# Running evaluation: 7it [00:00, 119.74it/s]
# Running evaluation: 7it [00:00, 120.63it/s]
# Running evaluation: 7it [00:00, 128.56it/s]
# Running evaluation: 7it [00:00, 122.77it/s]
# Running evaluation: 7it [00:00, 112.23it/s]
# Running evaluation: 7it [00:00, 120.76it/s]
# Running evaluation: 7it [00:00, 124.05it/s]
# Running evaluation: 7it [00:00, 121.76it/s]
# Running evaluation: 7it [00:00, 120.93it/s]
# Running evaluation: 7it [00:00, 122.55it/s]
# Running evaluation: 7it [00:00, 123.07it/s]
# Running evaluation: 7it [00:00, 125.45it/s]
# Running evaluation: 7it [00:00, 122.71it/s]
# Running evaluation: 7it [00:00, 123.98it/s]
# Running evaluation: 7it [00:00, 120.49it/s]
# Running evaluation: 7it [00:00, 119.71it/s]
# Running evaluation: 7it [00:00, 111.02it/s]
# Running evaluation: 7it [00:00, 116.14it/s]
# Running evaluation: 7it [00:00, 113.83it/s]
# Running evaluation: 7it [00:00, 118.18it/s]
# Running evaluation: 7it [00:00, 118.74it/s]
# Running evaluation: 7it [00:00, 123.56it/s]
# Running evaluation: 7it [00:00, 122.59it/s]
# Running evaluation: 7it [00:00, 118.52it/s]
# Running evaluation: 7it [00:00, 114.97it/s]
# Running evaluation: 7it [00:00, 88.75it/s]
# Running evaluation: 7it [00:00, 122.28it/s]
# Running evaluation: 7it [00:00, 126.22it/s]
# Running evaluation: 7it [00:00, 123.80it/s]
# Running evaluation: 7it [00:00, 117.55it/s]
# Running evaluation: 7it [00:00, 121.61it/s]
# Running evaluation: 7it [00:00, 126.72it/s]
# Running evaluation: 7it [00:00, 124.08it/s]
# Running evaluation: 7it [00:00, 115.82it/s]
# Running evaluation: 7it [00:00, 122.06it/s]
# Running evaluation: 7it [00:00, 105.12it/s]
# Running evaluation: 7it [00:00, 116.57it/s]
# Running evaluation: 7it [00:00, 119.40it/s]
# Running evaluation: 7it [00:00, 122.04it/s]
# Running evaluation: 7it [00:00, 33.06it/s]
# Running evaluation: 7it [00:00, 114.55it/s]
# Running evaluation: 7it [00:00, 39.90it/s]

# %%
print("CRPS:", agg_metric["mean_wQuantileLoss"])
print("ND:", agg_metric["ND"])
print("NRMSE:", agg_metric["NRMSE"])
print("")
print("CRPS-Sum:", agg_metric["m_sum_mean_wQuantileLoss"])
print("ND-Sum:", agg_metric["m_sum_ND"])
print("NRMSE-Sum:", agg_metric["m_sum_NRMSE"])
# Out:
# CRPS: 0.08424941525717067
# ND: 0.10891852326309058
# NRMSE: 0.894793435083521
#
# CRPS-Sum: 0.043186007671784425
# ND-Sum: 0.05814156381427675
# NRMSE-Sum: 0.07074610412482524
